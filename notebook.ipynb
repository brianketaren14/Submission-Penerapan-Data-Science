# %% [markdown]
# # Proyek Akhir: Menyelesaikan Permasalahan Perusahaan Edutech

# %% [markdown]
# - Nama: Brian Maxwell Ketaren
# - Email: brianketaren8@gmail.com
# - Id Dicoding: brianmaxwell

# %% [markdown]
# ## Persiapan

# %% [markdown]
# ### Menyiapkan library yang dibutuhkan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.ensemble import ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ### Menyiapkan data yang akan digunakan

# %%
df = pd.read_csv('data.csv', delimiter=';')

# %%
martial_status = []

for i in df['Marital status']:
  if i == 1:
    martial_status.append('Single')
  elif i == 2:
    martial_status.append('Married')
  elif i == 3:
    martial_status.append('Widower')
  elif i == 4:
    martial_status.append('Divorced')
  elif i == 5:
    martial_status.append('Facto Union')
  else:
    martial_status.append('Legally separated')

df['Marital status'] = martial_status

# %%
application_mode = []

for i in df['Application mode']:
  if i == 1:
    application_mode.append('1st phase - general contingent')
  elif i == 2:
    application_mode.append('Ordinance No. 612/93')
  elif i == 5:
    application_mode.append('1st phase - special contingent')
  elif i == 7:
    application_mode.append('Holders of other higher courses')
  elif i == 10:
    application_mode.append('Ordinance No. 854-B/99')
  elif i == 15:
    application_mode.append('International student (bachelor)')
  elif i == 16:
    application_mode.append('1st phase - special contingent (Madeira Island)')
  elif i == 17:
    application_mode.append('2nd phase - general contingent')
  elif i == 18:
    application_mode.append('3rd phase - general contingent')
  elif i == 26:
    application_mode.append('Ordinance No. 533-A/99, item b2')
  elif i == 27:
    application_mode.append(' Ordinance No. 533-A/99, item b3')
  elif i == 39:
    application_mode.append('Over 23 years old')
  elif i == 42:
    application_mode.append('Transfer')
  elif i == 43:
    application_mode.append('Change of course')
  elif i == 44:
    application_mode.append('Technological specialization diploma holders')
  elif i == 51:
    application_mode.append('Change of institution/course')
  elif i == 53:
    application_mode.append('Short cycle diploma holders')
  elif i == 57:
    application_mode.append('Change of institution/course (International)')

df['Application mode'] = application_mode

# %%
course = []

for i in df['Course']:
  if i == 33:
    course.append('Biofuel Production Technologies')
  elif i == 171:
    course.append('Animation and Multimedia Design')
  elif i == 8014:
    course.append('Social Service (evening attendance)')
  elif i == 9003:
    course.append('Agronomy')
  elif i == 9070:
    course.append('Communication Design')
  elif i == 9085:
    course.append('Veterinary Nursing')
  elif i == 9119:
    course.append('Informatics Engineering')
  elif i == 9130:
    course.append('Equinculture')
  elif i == 9147:
    course.append('Management')
  elif i == 9238:
    course.append('Social Service')
  elif i == 9254:
    course.append('Tourism')
  elif i == 9500:
    course.append('Nursing')
  elif i == 9556:
    course.append('Oral Hygiene')
  elif i == 9670:
    course.append('Advertising and Marketing Management')
  elif i == 9773:
    course.append('Journalism and Communication')
  elif i == 9853:
    course.append('Basic Education')
  elif i == 9991:
    course.append('Management (evening attendance)')

df['Course'] = course

# %%
previous_qualification = []
for i in df['Previous qualification']:
  if i == 1:
    previous_qualification.append('Secondary education')
  elif i == 2:
    previous_qualification.append("Higher education - bachelor's degree")
  elif i == 3:
    previous_qualification.append("Higher education - degree")
  elif i == 4:
    previous_qualification.append("Higher education - master's degree")
  elif i == 5:
    previous_qualification.append("Higher education - doctorate degree")
  elif i == 6:
    previous_qualification.append("Frequency of higher education")
  elif i == 9:
    previous_qualification.append(" 12th year of schooling - not completed")
  elif i == 10:
    previous_qualification.append("11th year of schooling - not completed")
  elif 1 == 12:
    previous_qualification.append("Other - 11th year of schooling")
  elif i == 14:
    previous_qualification.append("10th year of schooling")
  elif i == 15:
    previous_qualification.append("10th year of schooling - not completed")
  elif i == 19:
    previous_qualification.append("Basic education 3rd cycle (9th/10th/11th year) or equiv")
  elif i == 38:
    previous_qualification.append("Basic education 2nd cycle (6th/7th/8th year) or equiv")
  elif i == 39:
    previous_qualification.append("Technological specialization course")
  elif i == 40:
    previous_qualification.append("Higher education - degree (1st cycle)")
  elif i == 42:
    previous_qualification.append("Professional higher technical course")
  else:
    previous_qualification.append("Higher education - master (2nd cycle)")

df['Previous qualification'] = previous_qualification

# %%
nacionality = []

for i in df['Nacionality']:
  if i == 1:
    nacionality.append('Portuguese')
  elif i == 2:
    nacionality.append('German')
  elif i == 6:
    nacionality.append('Spanish')
  elif i == 11:
    nacionality.append('Italian')
  elif i == 13:
    nacionality.append('Dutch')
  elif i == 14:
    nacionality.append('English')
  elif i == 17:
    nacionality.append('Lithuanian')
  elif i == 21:
    nacionality.append('Angolan')
  elif i == 22:
    nacionality.append('Cape Verdean')
  elif i == 24:
    nacionality.append('Guinean')
  elif i == 25:
    nacionality.append('Mozambican')
  elif i == 26:
    nacionality.append('Santomean')
  elif i == 32:
    nacionality.append('Turkish')
  elif i == 41:
    nacionality.append('Brazilian')
  elif i == 62:
    nacionality.append('Romanian')
  elif i == 100:
    nacionality.append('Moldova (Republic of)')
  elif i == 101:
    nacionality.append('Mexican')
  elif i == 103:
    nacionality.append('Ukrainian')
  elif i == 105:
    nacionality.append('Russian')
  elif i == 108:
    nacionality.append('Cuban')
  elif i == 109:
    nacionality.append('Colombian')

df['Nacionality'] = nacionality

# %%
monther_qualification = []
for i in df["Mother's qualification"]:
  if i == 1:
    monther_qualification.append('Secondary education - 12th Year of Schooling or Eq.')
  elif i == 2:
    monther_qualification.append("Higher education - Bachelor's Degree")
  elif i == 3:
    monther_qualification.append("Higher education - Degree")
  elif i == 4:
    monther_qualification.append("Higher education - Master's Degree")
  elif i == 5:
    monther_qualification.append("Higher education - Doctorate Degree")
  elif i == 6:
    monther_qualification.append("Frequency of Higher Education")
  elif i == 9:
    monther_qualification.append("12th Year of Schooling - Not Completed")
  elif i == 10:
    monther_qualification.append("11th Year of Schooling - Not Completed")
  elif i == 11:
    monther_qualification.append("7th Year (Old)")
  elif i == 12:
    monther_qualification.append("Other - 11th Year of Schooling")
  elif i == 14:
    monther_qualification.append("10th Year of Schooling")
  elif i == 18:
    monther_qualification.append("General commerce course")
  elif i == 19:
    monther_qualification.append("Basic Education 3rd Cycle (9th/10th/11th Year) or Equivalent")
  elif i == 22:
    monther_qualification.append("Technical-professional course")
  elif i == 26:
    monther_qualification.append("7th year of schooling")
  elif i == 27:
    monther_qualification.append("2nd cycle of the general high school course")
  elif i == 29:
    monther_qualification.append("9th Year of Schooling - Not Completed")
  elif i == 30:
    monther_qualification.append("8th year of schooling")
  elif i == 34:
    monther_qualification.append("Unknown")
  elif i == 35:
    monther_qualification.append("Can't read or write")
  elif i == 36:
    monther_qualification.append("Can read without having a 4th year of schooling")
  elif i == 37:
    monther_qualification.append("Basic education 1st cycle (4th/5th year) or equiv")
  elif i == 38:
    monther_qualification.append("Basic education 2nd cycle (6th/7th/8th year) or equiv")
  elif i == 39:
    monther_qualification.append("Technological Specialization Course")
  elif i == 40:
    monther_qualification.append("Higher education - Degree (1st Cycle)")
  elif i == 41:
    monther_qualification.append("Specialized higher studies course")
  elif i == 42:
    monther_qualification.append("Professional higher technical course")
  elif i == 43:
    monther_qualification.append("Higher education - Master (2nd Cycle)")
  elif i == 44:
    monther_qualification.append("Higher education - Doctorate (3rd Cycle)")
df["Mother's qualification"] = monther_qualification

# %%
father_qualification = []

for i in df["Father's qualification"]:
  if i == 1:
    father_qualification.append('Secondary education - 12th Year of Schooling or Eq.')
  elif i == 2:
    father_qualification.append("Higher education - Bachelor's Degree")
  elif i == 3:
    father_qualification.append("Higher education - Degree")
  elif i == 4:
    father_qualification.append("Higher education - Master's Degree")
  elif i == 5:
    father_qualification.append("Higher education - Doctorate Degree")
  elif i == 6:
    father_qualification.append("Frequency of Higher Education")
  elif i == 9:
    father_qualification.append("12th Year of Schooling - Not Completed")
  elif i == 10:
    father_qualification.append("11th Year of Schooling - Not Completed")
  elif i == 11:
    father_qualification.append("7th Year (Old)")
  elif i == 12:
    father_qualification.append("Other - 11th Year of Schooling")
  elif i == 13:
    father_qualification.append(" 2nd year complementary high school course")
  elif i == 14:
    father_qualification.append("10th Year of Schooling")
  elif i == 18:
    father_qualification.append("General commerce course")
  elif i == 19:
    father_qualification.append("Basic Education 3rd Cycle (9th/10th/11th Year) or Equivalent")
  elif i == 20:
    father_qualification.append("Complementary High School Course")
  elif i == 22:
    father_qualification.append("Technical-professional course")
  elif i == 25:
    father_qualification.append("Complementary High School Course - not concluded")
  elif i == 26:
    father_qualification.append("7th year of schooling")
  elif i == 27:
    father_qualification.append("2nd cycle of the general high school course")
  elif i == 29:
    father_qualification.append("9th Year of Schooling - Not Completed")
  elif i == 30:
    father_qualification.append("8th year of schooling")
  elif i == 34:
    father_qualification.append("Unknown")
  elif i == 35:
    father_qualification.append("Can't read or write")
  elif i == 36:
    father_qualification.append("Can read without having a 4th year of schooling")
  elif i == 37:
    father_qualification.append("Basic education 1st cycle (4th/5th year) or equiv")
  elif i == 38:
    father_qualification.append("Basic education 2nd cycle (6th/7th/8th year) or equiv")
  elif i == 39:
    father_qualification.append("Technological Specialization Course")
  elif i == 40:
    father_qualification.append("Higher education - Degree (1st Cycle)")
  elif i == 41:
    father_qualification.append("Specialized higher studies course")
  elif i == 42:
    father_qualification.append("Professional higher technical course")
  elif i == 43:
    father_qualification.append("Higher education - Master (2nd Cycle)")
  else:
    father_qualification.append("Higher education - Doctorate (3rd Cycle)")

df["Father's qualification"] = father_qualification

# %%
mother_occupation = []
for i in df["Mother's occupation"]:
  if i == 0:
    mother_occupation.append('Student')
  elif i == 1:
    mother_occupation.append('Representatives of the Legislative Power and Executive Bodies, Directors, Directors and Executive Managers')
  elif i == 2:
    mother_occupation.append('Specialists in Intellectual and Scientific Activities')
  elif i == 3:
    mother_occupation.append('Intermediate Level Technicians and Professions')
  elif i == 4:
    mother_occupation.append('Administrative staff')
  elif i == 5:
    mother_occupation.append('Personal Services, Security and Safety Workers and Sellers')
  elif i == 6:
    mother_occupation.append('Farmers and Skilled Workers in Agriculture, Fisheries and Forestry')
  elif i == 7:
    mother_occupation.append('Skilled Workers in Industry, Construction and Craftsmen')
  elif i == 8:
    mother_occupation.append('Installation and Machine Operators and Assembly Workers')
  elif i == 9:
    mother_occupation.append('Unskilled Workers')
  elif i == 10:
    mother_occupation.append('Armed Forces Professions')
  elif i == 90:
    mother_occupation.append('Other Situation')
  elif i == 99:
    mother_occupation.append('(blank)')
  elif i == 122:
    mother_occupation.append('Health professionals')
  elif i == 123:
    mother_occupation.append('teachers')
  elif i == 125:
    mother_occupation.append('Specialists in information and communication technologies (ICT)')
  elif i == 131:
    mother_occupation.append('Intermediate level science and engineering technicians and professions')
  elif i == 132:
    mother_occupation.append('Technicians and professionals, of intermediate level of health')
  elif i == 134:
    mother_occupation.append('Intermediate level technicians from legal, social, sports, cultural and similar services')
  elif i == 141:
    mother_occupation.append('Office workers, secretaries in general and data processing operators')
  elif i == 143:
    mother_occupation.append('Data, accounting, statistical, financial services and registry-related operators')
  elif i == 144:
    mother_occupation.append('Other administrative support staff')
  elif i == 151:
    mother_occupation.append('personal service workers')
  elif i == 152:
    mother_occupation.append('sellers')
  elif i == 153:
    mother_occupation.append('Personal care workers and the like')
  elif i == 171:
    mother_occupation.append('Skilled construction workers and the like, except electricians')
  elif i == 173:
    mother_occupation.append('Skilled workers in printing, precision instrument manufacturing, jewelers, artisans and the like')
  elif i == 175:
    mother_occupation.append('Workers in food processing, woodworking, clothing and other industries and crafts')
  elif i == 191:
    mother_occupation.append('cleaning workers')
  elif i == 192:
    mother_occupation.append('Unskilled workers in agriculture, animal production, fisheries and forestry')
  elif i == 193:
    mother_occupation.append('Unskilled workers in extractive industry, construction, manufacturing and transport')
  elif i == 194:
    mother_occupation.append('Meal preparation assistants')

df["Mother's occupation"] = mother_occupation

# %%
father_occupation = []
for i in df["Father's occupation"]:
  if i == 0:
    father_occupation.append('Student')
  elif i == 1:
    father_occupation.append('Representatives of the Legislative Power and Executive Bodies, Directors, Directors and Executive Managers')
  elif i == 2:
    father_occupation.append('Specialists in Intellectual and Scientific Activities')
  elif i == 3:
    father_occupation.append('Intermediate Level Technicians and Professions')
  elif i == 4:
    father_occupation.append('Administrative staff')
  elif i == 5:
    father_occupation.append('Personal Services, Security and Safety Workers and Sellers')
  elif i == 6:
    father_occupation.append('Farmers and Skilled Workers in Agriculture, Fisheries and Forestry')
  elif i == 7:
    father_occupation.append('Skilled Workers in Industry, Construction and Craftsmen')
  elif i == 8:
    father_occupation.append('Installation and Machine Operators and Assembly Workers')
  elif i == 9:
    father_occupation.append('Unskilled Workers')
  elif i == 10:
    father_occupation.append('Armed Forces Professions')
  elif i == 90:
    father_occupation.append('Other Situation')
  elif i == 99:
    father_occupation.append('(blank)')
  elif i == 122:
    father_occupation.append('Health professionals')
  elif i == 123:
    father_occupation.append('teachers')
  elif i == 125:
    father_occupation.append('Specialists in information and communication technologies (ICT)')
  elif i == 131:
    father_occupation.append('Intermediate level science and engineering technicians and professions')
  elif i == 132:
    father_occupation.append('Technicians and professionals, of intermediate level of health')
  elif i == 134:
    father_occupation.append('Intermediate level technicians from legal, social, sports, cultural and similar services')
  elif i == 141:
    father_occupation.append('Office workers, secretaries in general and data processing operators')
  elif i == 143:
    father_occupation.append('Data, accounting, statistical, financial services and registry-related operators')
  elif i == 144:
    father_occupation.append('Other administrative support staff')
  elif i == 151:
    father_occupation.append('personal service workers')
  elif i == 152:
    father_occupation.append('sellers')
  elif i == 153:
    father_occupation.append('Personal care workers and the like')
  elif i == 171:
    father_occupation.append('Skilled construction workers and the like, except electricians')
  elif i == 173:
    father_occupation.append('Skilled workers in printing, precision instrument manufacturing, jewelers, artisans and the like')
  elif i == 175:
    father_occupation.append('Workers in food processing, woodworking, clothing and other industries and crafts')
  elif i == 191:
    father_occupation.append('cleaning workers')
  elif i == 192:
    father_occupation.append('Unskilled workers in agriculture, animal production, fisheries and forestry')
  elif i == 193:
    father_occupation.append('Unskilled workers in extractive industry, construction, manufacturing and transport')
  elif i == 194:
    father_occupation.append('Meal preparation assistants')

df["Father's occupation"] = mother_occupation

# %%
gender = []
for i in df['Gender']:
  if i == 1:
    gender.append('Male')
  else:
    gender.append('Female')

df['Gender'] = gender

# %%
df_cat = df[["Marital status", "Application mode", "Course", "Daytime/evening attendance	", "Previous qualification", "Nacionality", "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation", "Displaced", "Educational special needs", "Debtor", "Tuition fees up to date", "Gender", "Scholarship holder", "International"]]
df_num = df.drop(columns=["Marital status", "Application mode", "Course", "Daytime/evening attendance	", "Previous qualification", "Nacionality", "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation", "Displaced", "Educational special needs", "Debtor", "Tuition fees up to date", "Gender", "Scholarship holder", "International", "Target"])

# %%
df2 = df.copy()

# %% [markdown]
# ## Data Understanding

# %%
col = [0, 0, 0, 0]
row = [0, 1, 2, 3]
fig, axes = plt.subplots(4,5, figsize=(25,20))
index = 0
for i in df_num:
  if index < 5:
    sns.histplot(data=df, x=i, kde=True, ax=axes[row[0], col[0]], hue='Target')
    axes[row[0], col[0]].set_title(f'{i}')
    col[0] += 1
    index+=1
  elif index >= 5 and index < 10:
    sns.histplot(data=df, x=i, kde=True, ax=axes[row[1], col[1]], hue='Target')
    axes[row[1], col[1]].set_title(f'{i}')
    col[1] += 1
    index+=1
  elif index>=10 and index < 15:
    sns.histplot(data=df, x=i, kde=True, ax=axes[row[2], col[2]], hue='Target')
    axes[row[2], col[2]].set_title(f'{i}')
    col[2] += 1
    index+=1
  elif index>=15 and index < 20:
    sns.histplot(data=df, x=i, kde=True, ax=axes[row[3], col[3]], hue='Target')
    axes[row[3], col[3]].set_title(f'{i}')
    col[3] += 1
    index+=1
plt.tight_layout()
plt.show()

# %%
bfig, axes = plt.subplots(3,3, figsize=(12, 12))
row = [0, 1, 2]
col = [0, 0, 0]

for i in df_cat.drop(columns=["Application mode", "Course", "Previous qualification", "Nacionality", "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation"]):
  if col[0] < 3:
    sns.countplot(data=df, x=i, ax=axes[row[0], col[0]], hue='Target')
    axes[row[0], col[0]].set_title(f'{i}')
    col[0] += 1
  elif col[1] < 3:
    sns.countplot(data=df, x=i, ax=axes[row[1], col[1]], hue='Target')
    axes[row[1], col[1]].set_title(f'{i}')
    col[1] += 1
  else:
    sns.countplot(data=df, x=i, ax=axes[row[2], col[2]], hue='Target')
    axes[row[2], col[2]].set_title(f'{i}')
    col[2] += 1
plt.tight_layout()
plt.show()
# Out:
# C:\Users\GF63\AppData\Local\Temp\ipykernel_18140\677612329.py:18: UserWarning: Glyph 9 (	) missing from current font.
#   plt.tight_layout()
# C:\Users\GF63\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
for i in df_cat[["Application mode", "Course", "Previous qualification", "Nacionality", "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation"]]:
  plt.figure(figsize=(25, 5))
  sns.countplot(data=df, x=i, hue='Target')
  plt.xticks(rotation = -90)
  plt.show()

# %% [markdown]
# ## Data Preparation / Preprocessing

# %%
df = pd.get_dummies(df, columns = ['Marital status', 'Course', 'Application mode', 'Daytime/evening attendance	', 'Previous qualification', 'Nacionality', "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation"])

# %%
df = pd.get_dummies(df, columns=['Gender'], drop_first=True)

# %%
le = LabelEncoder()

df['Target'] = le.fit_transform(df['Target'])

# %%
df['Target'].value_counts()
# Out:
# Target
# 2    2209
# 0    1421
# 1     794
# Name: count, dtype: int64

# %%
df['Target'].value_counts()
# Out:
# Target
# 2    2209
# 0    1421
# 1     794
# Name: count, dtype: int64

# %%
scale = MinMaxScaler()
df[df_num.columns.tolist()] = scale.fit_transform(df_num)

# %%
x = df.drop(columns=['Target']) #independent feature
y = df['Target'] #target
y = to_categorical(y, num_classes=3)

# %%
model = ExtraTreesClassifier()
model.fit(x,y)
print(model.feature_importances_)
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# [1.33673555e-02 2.14416306e-02 2.28614620e-02 1.23538528e-02
#  1.61617209e-03 1.61492464e-02 5.19319248e-02 2.72962109e-02
#  2.25674765e-02 1.64663389e-03 6.04160142e-03 1.48350385e-02
#  2.85199028e-02 5.73072920e-02 4.88327719e-02 6.09869450e-03
#  5.57436079e-03 1.59841920e-02 3.18849868e-02 8.26827690e-02
#  7.10564971e-02 6.35843500e-03 1.89134249e-02 1.92000267e-02
#  1.88923599e-02 1.75883636e-03 5.50204440e-04 2.45729456e-04
#  3.35162506e-03 4.02764548e-03 3.10406745e-04 4.68713379e-03
#  2.59446568e-03 5.61143877e-03 7.24338069e-03 3.54632003e-04
#  3.69943212e-03 3.65949737e-03 7.77442852e-03 4.12908663e-03
#  6.03222781e-03 3.58739278e-03 9.60230660e-03 1.76300132e-03
#  6.27729749e-03 2.71061732e-03 4.38863042e-03 4.39563504e-03
#  3.96370768e-05 1.24273020e-02 8.37442599e-04 1.29524078e-03
#  7.19310098e-03 2.04460457e-03 5.44664802e-03 1.55398185e-03
#  3.67368082e-06 2.18010616e-03 9.66699886e-04 4.68070877e-05
# ...

# %%
features = feat_importances.nlargest(10).index.tolist()

# %%
features.append('Target')

# %%
df_slc = df[features]

# %%
df_slc.head()
# Out:
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                 0.00                          0.000000
# 1                                 0.30                          0.735897
# 2                                 0.00                          0.000000
# 3                                 0.25                          0.667692
# 4                                 0.30                          0.700000
#
#    Curricular units 1st sem (approved)  Tuition fees up to date  \
# 0                             0.000000                        1
# 1                             0.230769                        0
# 2                             0.000000                        0
# 3                             0.230769                        1
# 4                             0.192308                        1
#
#    Curricular units 1st sem (grade)  Curricular units 2nd sem (evaluations)  \
# ...

# %% [markdown]
# ## Modeling

# %%
x = df_slc.drop(columns=['Target'])
y = df_slc['Target']

# %%
y = to_categorical(y, num_classes=3)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = GradientBoostingClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %% [markdown]
# ## Evaluation

# %%
y_pred = model.predict(x_test)

# %%
y_pred_train_gbc = model.predict(x_train)
y_pred_test_gbc = model.predict(x_test)

accuracy_train_gbc = accuracy_score(y_pred_train_gbc, y_train)
accuracy_test_gbc = accuracy_score(y_pred_test_gbc, y_test)
 
# Menampilkan akurasi
print('Naive GBC - accuracy_train:', accuracy_train_gbc)
print('Naive GBC - accuracy_test:', accuracy_test_gbc)
# Out:
# Naive GBC - accuracy_train: 0.8070076292738062
# Naive GBC - accuracy_test: 0.727683615819209

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='g')
# Out:
# <Axes: >

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.72      0.77       316
#            1       0.39      0.30      0.34       151
#            2       0.76      0.89      0.81       418
#
#     accuracy                           0.73       885
#    macro avg       0.65      0.64      0.64       885
# weighted avg       0.72      0.73      0.72       885

# %%
import joblib

filename = "model/model.pickle"

# save model
joblib.dump(model, 'model.joblib')
# Out:
# ['model.joblib']

# %%
df2.to_csv('clean_df.csv', index=False)

# %% [markdown]
# ## Conclusion
#
# ### EDA
#
# - Siswa dropout kebanyakan memiliki application order 1.
# - Siswa dropout kebanyakan memiliki previous qualification grade sebesar 120-140.
# - Siswa droput kebanyakan memiliki admission grade sebesar 120-140.
# - Siswa dropout kebanyakan memiliki age at enrollment sebsear 15-20 tahun.
# - Siswa dropout kebanyakan memiliki curricular units 1st sem (credited) sebesar 0.
# - Siswa dropout kebanyakan memiliki curricular units 1st sem (enrolled) sebesar 5-6.
# - Siswa dropout kebanyakan memiliki curricular units 1st sem (evaluations) sebesar 0.
# -Siswa dropout kebanyakan memiliki curricular units 1st sem (approved) sebesar 0.
# - Siswa dropout kebanyakan memiliki martial status single.
# - Siswa dropout kebanyakan datang saat daytime.
# - Siswa dropout kebanyakan bukan displaced person.
# - Siswa dropout kebanyakan tidak membudtuhkan kebutuhan khusus,
# - Siswa dropout kebanyakan bukan seorang debtor.
# - Siswa dropout kebanyakan mempunyai biaya sekolah yang sesuai.
# - Siswa dropout kebanyakan memiliki gender perempuan dan laki-laki (seimbang).
# - Siswa dropout kebanyakan tidak memiliki beasiswa.
# - Siswa dropout kebanyakan bukan siswa international.
# - Siswa dropout kebanyakan memiliki application mode lewat 23 tahun.
# - Siswa dropout kebanyakan berasal dari course management.
# - Siswa dropout kebanyakan berasal dari secondary education.
# - Siswa dropout kebanyakan berasal dari negaral Portugal.
# - Siswa dropout kebanyakan memiliki mother's qualification Basic education 1st cycle (4th/5th year) or equiv.
# - Siswa dropout kebanyakan memiliki father's qualification Basic education 1st cycle (4th/5th year) or equiv.
# - Siswa dropout kebanyakan memiliki mother's occupation unskilled workers.
# - Siswa dropout kebanyakan memiliki father's occupation unskilled workers.
#
#
# ### Model
# - model good fit dengan accuracy perbedaan score accuracy train dan test sebesar 8%.
#
# ### Action Items
# 1. Intervensi Akademik
#
# - Tingkatkan Dukungan Akademik di Semester Pertama: Karena banyak siswa dropout memiliki nilai yang rendah dalam unit kurikuler semester pertama (0 kredit, 0 evaluasi, 0 disetujui), penting untuk memberikan dukungan akademik yang lebih intensif sejak awal. Program bimbingan, kelas tambahan, dan pengawasan lebih ketat bisa membantu siswa mengatasi kesulitan awal.
#
# - Program Pembelajaran dan Kelas Remedial: Untuk siswa dengan nilai penerimaan dan kualifikasi sebelumnya di kisaran 120-140, mungkin ada kebutuhan untuk menilai kembali kurikulum dan memastikan bahwa materi yang diajarkan sesuai dengan tingkat pengetahuan mereka. Menyediakan kelas remedial atau tutorial tambahan bisa mengurangi kesulitan akademik.
#
# 2. Dukungan Psikososial
# - Konseling dan Dukungan Kesejahteraan: Mengingat banyak siswa dropout yang berada pada rentang usia 15-20 tahun, usia yang sering kali menantang secara emosional, penting untuk menyediakan layanan konseling dan dukungan psikososial. Program konseling bisa membantu siswa mengatasi stres, tekanan, dan tantangan pribadi.
#
# - Program Orientasi dan Pembimbingan: Siswa yang datang pada waktu siang dan dari latar belakang pendidikan menengah mungkin merasa terisolasi. Program orientasi dan pembimbingan dapat membantu mereka beradaptasi dengan lingkungan akademik baru dan membangun jaringan sosial di kampus.
#
# 3. Strategi Keterlibatan dan Motivasi
# - Keterlibatan Orang Tua: Dengan banyak siswa memiliki orang tua dengan kualifikasi dan pekerjaan yang tidak terampil, melibatkan orang tua dalam proses pendidikan dan memberikan mereka informasi tentang cara mendukung anak-anak mereka di rumah bisa berkontribusi pada keberhasilan siswa.
#
# - Motivasi dan Penghargaan: Program motivasi yang mencakup penghargaan untuk pencapaian akademik atau kemajuan dalam kurikulum bisa menjadi insentif untuk siswa agar tetap terlibat dan berkomitmen pada studi mereka.
#
# 4. Pendekatan Administratif
# - Evaluasi dan Penyesuaian Aplikasi: Mengingat banyak siswa yang dropout mengajukan aplikasi lewat 23 tahun, mungkin perlu untuk menilai proses penerimaan dan memastikan bahwa siswa yang lebih muda atau baru lulus dari pendidikan menengah diprioritaskan dan diberikan dukungan tambahan.
#
# - Pemantauan dan Analisis Berkelanjutan: Mengembangkan sistem pemantauan yang dapat mengidentifikasi siswa yang berisiko tinggi untuk dropout lebih awal. Data ini harus digunakan untuk memberikan intervensi dini yang sesuai.
#
# 5. Penanganan Spesifik Berdasarkan Latar Belakang
# - Pendekatan untuk Kursus Management dan Pendidikan Sekunder: Karena banyak siswa yang dropout berasal dari kursus manajemen dan pendidikan menengah, menilai dan memperbaiki program studi di bidang ini serta menyesuaikan pendekatan pengajaran bisa membantu mengurangi angka dropout.
#
# - Menangani Biaya Sekolah: Memastikan bahwa biaya sekolah tidak menjadi kendala untuk siswa dan menyediakan bantuan keuangan atau beasiswa tambahan bagi mereka yang membutuhkan dapat membantu dalam mengurangi dropout.
#
# 6. Diversifikasi dan Inklusi
# - Meningkatkan Program Inklusi: Walaupun sebagian besar dropout bukan siswa internasional, penting untuk memastikan bahwa semua siswa, termasuk siswa internasional, merasa diterima dan mendapatkan dukungan yang diperlukan untuk berhasil di akademik.
# - Dengan mengikuti langkah-langkah ini, diharapkan dapat mengurangi angka dropout dan meningkatkan tingkat keberhasilan siswa secara keseluruhan.
